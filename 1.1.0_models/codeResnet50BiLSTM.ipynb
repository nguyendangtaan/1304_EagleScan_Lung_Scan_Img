# %%
import os
import cv2
import numpy as np
import pydicom
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import albumentations as A
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils import class_weight
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input as resnet_preprocess
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.regularizers import l2

# ============================= CONFIG =============================
SEQUENCE_LENGTH = 10
TARGET_CENTER = 20
IMG_SIZE = 224
BATCH_SIZE = 8
EPOCHS_BINARY = 30 
EPOCHS_TRI = 200 
LUNG_PET_DIR = "/kaggle/input/lung-pet-ct-dx/Lung-PET-CT-Dx"
NORMAL_DIR = "/kaggle/input/d/tnnguynng/normal/Normal"
target_names_binary = ["Normal", "Abnormal"]
target_names_tri = ["Adeno", "Small", "Squamous"]

# ========================= PREPROCESSING =========================
def apply_window(img_hu, ww, wl):
    img_min = wl - ww / 2
    img_max = wl + ww / 2
    img = np.clip(img_hu, img_min, img_max)
    return ((img - img_min) / ww * 255).astype(np.uint8)

def read_image_general(path):
    if path.lower().endswith(".dcm"):
        try:
            dicom = pydicom.dcmread(path)
            img = dicom.pixel_array.astype(np.float32)
            if hasattr(dicom, 'RescaleSlope'):
                img = img * dicom.RescaleSlope + dicom.RescaleIntercept
            return img
        except:
            return None
    else:
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        return img.astype(np.float32) if img is not None else None

# ========================= AUGMENTATION =========================
train_aug = A.ReplayCompose([
    A.HorizontalFlip(p=0.5),
    A.RandomRotate90(p=0.6),
    A.ShiftScaleRotate(shift_limit=0.2, scale_limit=0.2, rotate_limit=45, p=0.7),
    A.RandomBrightnessContrast(brightness_limit=0.4, contrast_limit=0.4, p=0.7),
    A.CLAHE(clip_limit=4.0, p=0.5), 
    A.Sharpen(p=0.3),             
    A.GaussNoise(var_limit=(10, 50), p=0.3), 
    A.CoarseDropout(max_holes=6, max_height=20, max_width=20, p=0.3),
], p=1.0)

# ========================= DATA GENERATOR =========================
class SequenceDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, x_files, y, batch_size, shuffle=True, aug=None):
        self.x_files = x_files
        self.y = y
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.aug = aug
        self.indices = np.arange(len(self.x_files))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.x_files) / self.batch_size))

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __getitem__(self, index):
        idx = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        batch_x = [self.x_files[i] for i in idx]
        batch_y = self.y[idx]
        X = []
        for seq in batch_x:
            seq_imgs = []
            replay = None
            for i, (path, _) in enumerate(seq):
                img_hu = read_image_general(path)
                if img_hu is None:
                    img_hu = np.zeros((IMG_SIZE, IMG_SIZE))

                if path.lower().endswith(".dcm"):
                    img_l = apply_window(img_hu, 1500, -600)
                    medi = apply_window(img_hu, 350, 40)
                else:
                    img_gray = cv2.resize(img_hu.astype(np.uint8), (IMG_SIZE, IMG_SIZE))
                    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
                    img_l = clahe.apply(img_gray)
                    medi = clahe.apply(img_gray)

                img_l = cv2.resize(img_l, (IMG_SIZE, IMG_SIZE))
                medi = cv2.resize(medi, (IMG_SIZE, IMG_SIZE))

                if self.aug:
                    if i == 0:
                        res = self.aug(image=img_l)
                        replay = res["replay"]
                        img_aug = res["image"]
                    else:
                        img_aug = A.ReplayCompose.replay(replay, image=img_l)["image"]
                else:
                    img_aug = img_l

                final = cv2.merge([img_aug, medi, cv2.Canny(img_aug, 100, 200)])
                seq_imgs.append(resnet_preprocess(final.astype(np.float32)))

            X.append(np.stack(seq_imgs))
        return np.array(X), batch_y

# ========================= VISUALIZATION =========================
def plot_history(history, phase_name):
    metrics = ['loss', 'accuracy', 'auc']
    plt.figure(figsize=(18, 5))
    for i, m in enumerate(metrics):
        plt.subplot(1, 3, i+1)
        plt.plot(history.history[m], label='Train')
        plt.plot(history.history[f'val_{m}'], label='Val')
        plt.title(f'{phase_name} - {m.upper()}')
        plt.xlabel('Epochs')
        plt.legend()
    plt.tight_layout()
    plt.show()

# ========================= LOAD DATA =========================
def build_patient_data(directory, label_map):
    patients_info = []
    for folder in sorted(os.listdir(directory)):
        label_char = folder.split('-')[1][0] if '-' in folder else folder[0]
        if label_char not in label_map:
            continue
        path = os.path.join(directory, folder)
        all_series = []
        for root, _, files in os.walk(path):
            imgs = [os.path.join(root, f) for f in files if f.lower().endswith('.dcm')]
            if len(imgs) >= SEQUENCE_LENGTH:
                imgs.sort()
                all_series.append([(f, label_map[label_char]) for f in imgs])
        if all_series:
            patients_info.append((folder, label_map[label_char], all_series))
    return patients_info

def load_binary_data():
    X, y, p_ids = [], [], []
    label_map = {'A': 0, 'B': 1, 'G': 2}
    patients_info = build_patient_data(LUNG_PET_DIR, label_map)
    for p_id, label, series in patients_info:
        for slices in series:
            n = len(slices)
            target = 20 if n > 30 else (10 if n >= 10 else n)
            center = slices[(n - target) // 2 : (n - target) // 2 + target]
            for i in range(0, len(center) - SEQUENCE_LENGTH + 1, 2):
                X.append(center[i:i + SEQUENCE_LENGTH])
                y.append(1)  # Abnormal
                p_ids.append(p_id)

    all_subfolders = sorted([f for f in os.listdir(NORMAL_DIR) if os.path.isdir(os.path.join(NORMAL_DIR, f))])
    patient_to_subfolders = {}
    for sub in all_subfolders:
        patient_id = sub.split('_')[0]
        if patient_id not in patient_to_subfolders:
            patient_to_subfolders[patient_id] = []
        patient_to_subfolders[patient_id].append(sub)

    normal_count = 0
    for patient_id, sub_list in patient_to_subfolders.items():
        chosen_sub = sorted(sub_list)[0]
        sub_path = os.path.join(NORMAL_DIR, chosen_sub)
        imgs = []
        for root, _, files in os.walk(sub_path):
            for file in files:
                if file.lower().endswith(".png"):
                    imgs.append(os.path.join(root, file))
        imgs.sort()
        if len(imgs) < TARGET_CENTER:
            continue
        start = (len(imgs) - TARGET_CENTER) // 2
        center_imgs = imgs[start:start + TARGET_CENTER]
        for i in range(0, len(center_imgs) - SEQUENCE_LENGTH + 1, 2):
            seq = [(p, 3) for p in center_imgs[i:i + SEQUENCE_LENGTH]]
            X.append(seq)
            y.append(0)  # Normal
            p_ids.append(f"Normal_{patient_id}")
        normal_count += 1

    print(f"[INFO] Binary: {normal_count} bệnh nhân Normal + ung thư")
    y_cat = tf.keras.utils.to_categorical(y, num_classes=2)
    return np.array(X, dtype=object), y_cat, np.array(p_ids)

def load_tri_data():
    X, y, p_ids = [], [], []
    label_map = {'A': 0, 'B': 1, 'G': 2}
    patients_info = build_patient_data(LUNG_PET_DIR, label_map)
    for p_id, label, series in patients_info:
        for slices in series:
            n = len(slices)
            target = 20 if n > 30 else (10 if n >= 10 else n)
            center = slices[(n - target) // 2 : (n - target) // 2 + target]
            for i in range(0, len(center) - SEQUENCE_LENGTH + 1, 2):
                X.append(center[i:i + SEQUENCE_LENGTH])
                y.append(label)
                p_ids.append(p_id)
    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)
    return np.array(X, dtype=object), y_cat, np.array(p_ids)

# ========================= GIAI ĐOẠN 1: BINARY =========================
print("=== GIAI ĐOẠN 1: BINARY CLASSIFICATION (Normal vs Abnormal) ===")
X_bin, y_bin, p_ids_bin = load_binary_data()

unique_pts_bin, first_idx_bin = np.unique(p_ids_bin, return_index=True)
patient_labels_bin = np.argmax(y_bin[first_idx_bin], axis=1)

p_train_bin, p_temp_bin, lbl_train_bin, lbl_temp_bin = train_test_split(unique_pts_bin, patient_labels_bin, test_size=0.3, stratify=patient_labels_bin, random_state=42)
p_val_bin, p_test_bin, lbl_val_bin, lbl_test_bin = train_test_split(p_temp_bin, lbl_temp_bin, test_size=0.333, stratify=lbl_temp_bin, random_state=42)

print("\n--- PHÂN BỐ BỆNH NHÂN BINARY ---")
print(f"Train: {len(p_train_bin)} bệnh nhân ({len(lbl_train_bin) - np.sum(lbl_train_bin)} Normal, {np.sum(lbl_train_bin)} Abnormal)")
print(f"Val: {len(p_val_bin)} bệnh nhân ({len(lbl_val_bin) - np.sum(lbl_val_bin)} Normal, {np.sum(lbl_val_bin)} Abnormal)")
print(f"Test: {len(p_test_bin)} bệnh nhân ({len(lbl_test_bin) - np.sum(lbl_test_bin)} Normal, {np.sum(lbl_test_bin)} Abnormal)")

idx_train_bin = np.isin(p_ids_bin, p_train_bin)
idx_val_bin = np.isin(p_ids_bin, p_val_bin)
idx_test_bin = np.isin(p_ids_bin, p_test_bin)

train_gen_bin = SequenceDataGenerator(X_bin[idx_train_bin], y_bin[idx_train_bin], BATCH_SIZE, aug=train_aug)
val_gen_bin = SequenceDataGenerator(X_bin[idx_val_bin], y_bin[idx_val_bin], BATCH_SIZE, shuffle=False)
test_gen_bin = SequenceDataGenerator(X_bin[idx_test_bin], y_bin[idx_test_bin], BATCH_SIZE, shuffle=False)

def attention_block(inputs):
    u = Dense(inputs.shape[-1], activation="tanh")(inputs)
    alpha = Softmax(axis=1)(Dense(1)(u))
    return Lambda(lambda x: tf.reduce_sum(x[0] * x[1], axis=1))([inputs, alpha])

def build_binary_model():
    inp = Input(shape=(SEQUENCE_LENGTH, IMG_SIZE, IMG_SIZE, 3))
    base = ResNet50(weights="imagenet", include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
    base.trainable = True
    for layer in base.layers[:-20]:
        layer.trainable = False
    x = TimeDistributed(base)(inp)
    x = TimeDistributed(GlobalAveragePooling2D())(x)
    x = TimeDistributed(Dense(256, activation="relu"))(x)
    x = Bidirectional(LSTM(32, return_sequences=True))(x)
    x = attention_block(LayerNormalization()(x))
    x = Dense(128, activation="relu", kernel_regularizer=l2(0.02))(x)
    out = Dense(2, activation="softmax")(Dropout(0.6)(x))
    model = Model(inp, out)
    model.compile(optimizer=AdamW(learning_rate=5e-5, weight_decay=1e-4),
                  loss=tf.keras.losses.CategoricalFocalCrossentropy(gamma=2.0),
                  metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])
    return model

model_binary = build_binary_model()

callbacks_binary = [
    EarlyStopping(monitor='val_auc', mode='max', patience=20, restore_best_weights=True),
    ModelCheckpoint("binary_best.h5", save_best_only=True, monitor="val_auc", mode="max"),
    ReduceLROnPlateau(monitor="val_auc", mode='max', factor=0.5, patience=10)
]

history_binary = model_binary.fit(train_gen_bin, validation_data=val_gen_bin, epochs=EPOCHS_BINARY, callbacks=callbacks_binary)
plot_history(history_binary, "Binary Classification") # Vẽ biểu đồ

# Evaluation Binary
model_binary.load_weights("binary_best.h5")
test_preds_bin = model_binary.predict(test_gen_bin)

print("\n" + "="*60)
print("BINARY RESULT - SEQUENCE LEVEL")
y_true_seq_bin = np.argmax(y_bin[idx_test_bin], axis=1)
y_pred_seq_bin = np.argmax(test_preds_bin, axis=1)
print(classification_report(y_true_seq_bin, y_pred_seq_bin, target_names=target_names_binary, zero_division=0))

print("\nBINARY RESULT - PATIENT LEVEL (CONFIDENCE-WEIGHTED)")
y_true_pat_bin, y_pred_pat_bin = [], []
for p in p_test_bin:
    idx = np.where(p_ids_bin[idx_test_bin] == p)[0]
    if len(idx) > 0:
        p_preds = test_preds_bin[idx]
        # Thay đổi cơ chế voting sang Weighted: nhân với độ tự tin cực đại
        confidences = np.max(p_preds, axis=1, keepdims=True)
        weighted_avg = np.sum(p_preds * confidences, axis=0) / (np.sum(confidences) + 1e-7)
        y_pred_pat_bin.append(np.argmax(weighted_avg))
        y_true_pat_bin.append(patient_labels_bin[np.where(unique_pts_bin == p)[0][0]])

print(classification_report(y_true_pat_bin, y_pred_pat_bin, target_names=target_names_binary, zero_division=0))

# Confusion Matrix Binary
fig, ax = plt.subplots(1, 2, figsize=(14, 5))
sns.heatmap(confusion_matrix(y_true_seq_bin, y_pred_seq_bin, labels=range(2)), annot=True, fmt='d', cmap='Blues',
            xticklabels=target_names_binary, yticklabels=target_names_binary, ax=ax[0])
ax[0].set_title("Binary - Sequence Level")
sns.heatmap(confusion_matrix(y_true_pat_bin, y_pred_pat_bin, labels=range(2)), annot=True, fmt='d', cmap='Blues',
            xticklabels=target_names_binary, yticklabels=target_names_binary, ax=ax[1])
ax[1].set_title("Binary - Patient Level")
plt.tight_layout()
plt.show()

# ========================= GIAI ĐOẠN 2: TRI-CLASS =========================
print("\n=== GIAI ĐOẠN 2: TRI-CLASS CLASSIFICATION (Adeno, Small, Squamous) ===")
X_tri, y_tri, p_ids_tri = load_tri_data()

unique_pts_tri, first_idx_tri = np.unique(p_ids_tri, return_index=True)
patient_labels_tri = np.argmax(y_tri[first_idx_tri], axis=1)

p_train_tri, p_temp_tri, lbl_train_tri, lbl_temp_tri = train_test_split(unique_pts_tri, patient_labels_tri, test_size=0.3, stratify=patient_labels_tri, random_state=42)
p_val_tri, p_test_tri, lbl_val_tri, lbl_test_tri = train_test_split(p_temp_tri, lbl_temp_tri, test_size=0.333, stratify=lbl_temp_tri, random_state=42)

print("\n--- PHÂN BỐ BỆNH NHÂN TRI-CLASS ---")
for name, lbl in zip(["Train", "Val", "Test"], [lbl_train_tri, lbl_val_tri, lbl_test_tri]):
    u, c = np.unique(lbl, return_counts=True)
    print(f"{name}: {len(lbl)} bệnh nhân")
    for i, count in zip(u, c):
        print(f"  - {target_names_tri[i]}: {count}")

idx_train_tri = np.isin(p_ids_tri, p_train_tri)
idx_val_tri = np.isin(p_ids_tri, p_val_tri)
idx_test_tri = np.isin(p_ids_tri, p_test_tri)

train_gen_tri = SequenceDataGenerator(X_tri[idx_train_tri], y_tri[idx_train_tri], BATCH_SIZE, aug=train_aug)
val_gen_tri = SequenceDataGenerator(X_tri[idx_val_tri], y_tri[idx_val_tri], BATCH_SIZE, shuffle=False)
test_gen_tri = SequenceDataGenerator(X_tri[idx_test_tri], y_tri[idx_test_tri], BATCH_SIZE, shuffle=False)

def build_tri_model():
    inp = Input(shape=(SEQUENCE_LENGTH, IMG_SIZE, IMG_SIZE, 3))
    base = ResNet50(weights="imagenet", include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
    base.trainable = True
    for layer in base.layers[:-20]:
        layer.trainable = False
    x = TimeDistributed(base)(inp)
    x = TimeDistributed(GlobalAveragePooling2D())(x)
    x = TimeDistributed(Dense(256, activation="relu"))(x)
    x = Bidirectional(LSTM(32, return_sequences=True))(x)
    x = attention_block(LayerNormalization()(x))
    x = Dense(128, activation="relu", kernel_regularizer=l2(0.02))(x)
    out = Dense(3, activation="softmax")(Dropout(0.6)(x))
    model = Model(inp, out)
    loss_fn = tf.keras.losses.CategoricalFocalCrossentropy(
        gamma=3.0,          # Tăng gamma để tập trung mẫu khó
        alpha=[0.3, 0.5, 0.2] # Ép trọng số lớp: Small(0.5) > Adeno(0.3) > Squamous(0.2)
    )
    model.compile(optimizer=AdamW(learning_rate=3e-5, weight_decay=1e-4),
                  loss=loss_fn,
                  metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])
    return model

model_tri = build_tri_model()
model_tri.load_weights("binary_best.h5", by_name=True, skip_mismatch=True)

callbacks_tri = [
    EarlyStopping(monitor='val_auc', mode='max', patience=30, restore_best_weights=True),
    ModelCheckpoint("tri_best.h5", save_best_only=True, monitor="val_auc", mode="max"),
    ReduceLROnPlateau(monitor="val_auc", mode='max', factor=0.5, patience=15)
]

history_tri = model_tri.fit(train_gen_tri, validation_data=val_gen_tri, epochs=EPOCHS_TRI, callbacks=callbacks_tri)
plot_history(history_tri, "Tri-class Classification") # Vẽ biểu đồ

# Final evaluation tri-class
model_tri.load_weights("tri_best.h5")
test_preds_tri = model_tri.predict(test_gen_tri)

print("\n" + "="*60)
print("TRI-CLASS RESULT - SEQUENCE LEVEL")
y_true_seq_tri = np.argmax(y_tri[idx_test_tri], axis=1)
y_pred_seq_tri = np.argmax(test_preds_tri, axis=1)
print(classification_report(y_true_seq_tri, y_pred_seq_tri, target_names=target_names_tri, zero_division=0))

print("\nTRI-CLASS RESULT - PATIENT LEVEL (CONFIDENCE-WEIGHTED)")
y_true_pat_tri, y_pred_pat_tri = [], []
for p in p_test_tri:
    idx = np.where(p_ids_tri[idx_test_tri] == p)[0]
    if len(idx) > 0:
        p_preds = test_preds_tri[idx]
        # Thay đổi cơ chế voting sang Weighted: nhân với độ tự tin cực đại
        confidences = np.max(p_preds, axis=1, keepdims=True)
        weighted_avg = np.sum(p_preds * confidences, axis=0) / (np.sum(confidences) + 1e-7)
        y_pred_pat_tri.append(np.argmax(weighted_avg))
        y_true_pat_tri.append(patient_labels_tri[np.where(unique_pts_tri == p)[0][0]])

print(classification_report(y_true_pat_tri, y_pred_pat_tri, target_names=target_names_tri, zero_division=0))

# Confusion Matrix Tri-class
fig, ax = plt.subplots(1, 2, figsize=(16, 6))
sns.heatmap(confusion_matrix(y_true_seq_tri, y_pred_seq_tri, labels=range(3)), annot=True, fmt='d', cmap='Blues',
            xticklabels=target_names_tri, yticklabels=target_names_tri, ax=ax[0])
ax[0].set_title("Tri-class - Sequence Level")
sns.heatmap(confusion_matrix(y_true_pat_tri, y_pred_pat_tri, labels=range(3)), annot=True, fmt='d', cmap='Blues',
            xticklabels=target_names_tri, yticklabels=target_names_tri, ax=ax[1])
ax[1].set_title("Tri-class - Patient Level")
plt.tight_layout()
plt.show()
# Out:
# 2026-01-03 09:21:03.779584: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767432064.133883      38 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767432064.233076      38 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /tmp/ipykernel_38/861600678.py:61: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10, 50), p=0.3),
# /tmp/ipykernel_38/861600678.py:62: UserWarning: Argument(s) 'max_holes, max_height, max_width' are not valid for transform CoarseDropout
#   A.CoarseDropout(max_holes=6, max_height=20, max_width=20, p=0.3),
# === GIAI ĐOẠN 1: BINARY CLASSIFICATION (Normal vs Abnormal) ===
# [INFO] Binary: 19 bệnh nhân Normal + ung thư
#
# --- PHÂN BỐ BỆNH NHÂN BINARY ---
# Train: 81 bệnh nhân (13 Normal, 68 Abnormal)
# Val: 24 bệnh nhân (4 Normal, 20 Abnormal)
# Test: 12 bệnh nhân (2 Normal, 10 Abnormal)
# I0000 00:00:1767432115.912642      38 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1767432115.913336      38 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/30
# I0000 00:00:1767432236.819878      99 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 234s 2s/step - accuracy: 0.7911 - auc: 0.8649 - loss: 1.7224 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.6264 - learning_rate: 5.0000e-05
# Epoch 2/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9651 - auc: 0.9933 - loss: 1.6161 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.5602 - learning_rate: 5.0000e-05
# Epoch 3/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9937 - auc: 0.9998 - loss: 1.5455 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.4948 - learning_rate: 5.0000e-05
# Epoch 4/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9760 - auc: 0.9984 - loss: 1.4823 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.4307 - learning_rate: 5.0000e-05
# Epoch 5/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9918 - auc: 0.9999 - loss: 1.4161 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.3682 - learning_rate: 5.0000e-05
# Epoch 6/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9988 - auc: 0.9999 - loss: 1.3538 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.3075 - learning_rate: 5.0000e-05
# Epoch 7/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9955 - auc: 0.9973 - loss: 1.2956 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.2487 - learning_rate: 5.0000e-05
# Epoch 8/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9945 - auc: 0.9998 - loss: 1.2356 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.1919 - learning_rate: 5.0000e-05
# Epoch 9/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9983 - auc: 1.0000 - loss: 1.1787 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.1371 - learning_rate: 5.0000e-05
# Epoch 10/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9997 - auc: 1.0000 - loss: 1.1240 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.0842 - learning_rate: 5.0000e-05
# Epoch 11/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.0717 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.0333 - learning_rate: 5.0000e-05
# Epoch 12/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9943 - auc: 1.0000 - loss: 1.0278 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 1.0085 - learning_rate: 2.5000e-05
# Epoch 13/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9970 - auc: 0.9999 - loss: 1.0031 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.9840 - learning_rate: 2.5000e-05
# Epoch 14/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.9788 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.9598 - learning_rate: 2.5000e-05
# Epoch 15/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.9545 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.9360 - learning_rate: 2.5000e-05
# Epoch 16/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.9305 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.9126 - learning_rate: 2.5000e-05
# Epoch 17/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9998 - auc: 1.0000 - loss: 0.9070 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.8895 - learning_rate: 2.5000e-05
# Epoch 18/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9988 - auc: 1.0000 - loss: 0.8844 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.8668 - learning_rate: 2.5000e-05
# Epoch 19/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.8615 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.8445 - learning_rate: 2.5000e-05
# Epoch 20/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.8393 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.8226 - learning_rate: 2.5000e-05
# Epoch 21/30
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9969 - auc: 0.9999 - loss: 0.8179 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.8010 - learning_rate: 2.5000e-05
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 61s 5s/step
#
# ============================================================
# BINARY RESULT - SEQUENCE LEVEL
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00        12
#     Abnormal       1.00      1.00      1.00        45
#
#     accuracy                           1.00        57
#    macro avg       1.00      1.00      1.00        57
# weighted avg       1.00      1.00      1.00        57
#
#
# BINARY RESULT - PATIENT LEVEL (CONFIDENCE-WEIGHTED)
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00         2
#     Abnormal       1.00      1.00      1.00        10
#
#     accuracy                           1.00        12
#    macro avg       1.00      1.00      1.00        12
# weighted avg       1.00      1.00      1.00        12
# === GIAI ĐOẠN 2: TRI-CLASS CLASSIFICATION (Adeno, Small, Squamous) ===
#
# --- PHÂN BỐ BỆNH NHÂN TRI-CLASS ---
# Train: 68 bệnh nhân
#   - Adeno: 28
#   - Small: 19
#   - Squamous: 21
# Val: 20 bệnh nhân
#   - Adeno: 8
#   - Small: 6
#   - Squamous: 6
# Test: 10 bệnh nhân
#   - Adeno: 4
#   - Small: 3
#   - Squamous: 3
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# /usr/local/lib/python3.11/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# Epoch 1/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 195s 2s/step - accuracy: 0.3653 - auc: 0.5255 - loss: 1.9248 - val_accuracy: 0.3267 - val_auc: 0.5364 - val_loss: 1.7937 - learning_rate: 3.0000e-05
# Epoch 2/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.3907 - auc: 0.5549 - loss: 1.8350 - val_accuracy: 0.3366 - val_auc: 0.5275 - val_loss: 1.7735 - learning_rate: 3.0000e-05
# Epoch 3/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.3777 - auc: 0.5384 - loss: 1.8075 - val_accuracy: 0.4158 - val_auc: 0.5869 - val_loss: 1.7440 - learning_rate: 3.0000e-05
# Epoch 4/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.3389 - auc: 0.5458 - loss: 1.7713 - val_accuracy: 0.4455 - val_auc: 0.6313 - val_loss: 1.7116 - learning_rate: 3.0000e-05
# Epoch 5/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.4075 - auc: 0.5988 - loss: 1.7379 - val_accuracy: 0.4257 - val_auc: 0.6360 - val_loss: 1.6890 - learning_rate: 3.0000e-05
# Epoch 6/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.3683 - auc: 0.5633 - loss: 1.7193 - val_accuracy: 0.3960 - val_auc: 0.5854 - val_loss: 1.6724 - learning_rate: 3.0000e-05
# Epoch 7/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.3610 - auc: 0.5489 - loss: 1.6953 - val_accuracy: 0.3663 - val_auc: 0.6029 - val_loss: 1.6489 - learning_rate: 3.0000e-05
# Epoch 8/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.4108 - auc: 0.6110 - loss: 1.6573 - val_accuracy: 0.3762 - val_auc: 0.5487 - val_loss: 1.6352 - learning_rate: 3.0000e-05
# Epoch 9/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.4445 - auc: 0.6374 - loss: 1.6277 - val_accuracy: 0.4356 - val_auc: 0.5957 - val_loss: 1.6060 - learning_rate: 3.0000e-05
# Epoch 10/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.3559 - auc: 0.5504 - loss: 1.6138 - val_accuracy: 0.3960 - val_auc: 0.6265 - val_loss: 1.5809 - learning_rate: 3.0000e-05
# Epoch 11/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.3816 - auc: 0.5886 - loss: 1.5898 - val_accuracy: 0.5743 - val_auc: 0.7274 - val_loss: 1.5533 - learning_rate: 3.0000e-05
# Epoch 12/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.4158 - auc: 0.6432 - loss: 1.5608 - val_accuracy: 0.3564 - val_auc: 0.6033 - val_loss: 1.5401 - learning_rate: 3.0000e-05
# Epoch 13/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.4167 - auc: 0.6307 - loss: 1.5438 - val_accuracy: 0.3564 - val_auc: 0.5983 - val_loss: 1.5169 - learning_rate: 3.0000e-05
# Epoch 14/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.4199 - auc: 0.6244 - loss: 1.5196 - val_accuracy: 0.4851 - val_auc: 0.6590 - val_loss: 1.4976 - learning_rate: 3.0000e-05
# Epoch 15/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.4601 - auc: 0.6653 - loss: 1.4883 - val_accuracy: 0.6040 - val_auc: 0.7436 - val_loss: 1.4712 - learning_rate: 3.0000e-05
# Epoch 16/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.4600 - auc: 0.6507 - loss: 1.4698 - val_accuracy: 0.6337 - val_auc: 0.7665 - val_loss: 1.4400 - learning_rate: 3.0000e-05
# Epoch 17/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.4529 - auc: 0.6872 - loss: 1.4441 - val_accuracy: 0.5842 - val_auc: 0.7902 - val_loss: 1.4171 - learning_rate: 3.0000e-05
# Epoch 18/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.4729 - auc: 0.6982 - loss: 1.4201 - val_accuracy: 0.6634 - val_auc: 0.8329 - val_loss: 1.3873 - learning_rate: 3.0000e-05
# Epoch 19/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.4752 - auc: 0.7104 - loss: 1.3984 - val_accuracy: 0.6040 - val_auc: 0.8155 - val_loss: 1.3758 - learning_rate: 3.0000e-05
# Epoch 20/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.5069 - auc: 0.7261 - loss: 1.3778 - val_accuracy: 0.5743 - val_auc: 0.7620 - val_loss: 1.3493 - learning_rate: 3.0000e-05
# Epoch 21/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.4788 - auc: 0.7056 - loss: 1.3648 - val_accuracy: 0.4455 - val_auc: 0.7111 - val_loss: 1.3375 - learning_rate: 3.0000e-05
# Epoch 22/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.5505 - auc: 0.7513 - loss: 1.3301 - val_accuracy: 0.5347 - val_auc: 0.7574 - val_loss: 1.3099 - learning_rate: 3.0000e-05
# Epoch 23/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.5533 - auc: 0.7397 - loss: 1.3111 - val_accuracy: 0.4455 - val_auc: 0.7154 - val_loss: 1.2903 - learning_rate: 3.0000e-05
# Epoch 24/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.5169 - auc: 0.7074 - loss: 1.2971 - val_accuracy: 0.5248 - val_auc: 0.7638 - val_loss: 1.2636 - learning_rate: 3.0000e-05
# Epoch 25/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.5515 - auc: 0.7831 - loss: 1.2674 - val_accuracy: 0.6139 - val_auc: 0.7659 - val_loss: 1.2950 - learning_rate: 3.0000e-05
# Epoch 26/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.5451 - auc: 0.7613 - loss: 1.2502 - val_accuracy: 0.6535 - val_auc: 0.7889 - val_loss: 1.2552 - learning_rate: 3.0000e-05
# Epoch 27/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.5786 - auc: 0.7516 - loss: 1.2367 - val_accuracy: 0.6238 - val_auc: 0.7841 - val_loss: 1.2302 - learning_rate: 3.0000e-05
# Epoch 28/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.5994 - auc: 0.7791 - loss: 1.2108 - val_accuracy: 0.6139 - val_auc: 0.7863 - val_loss: 1.2016 - learning_rate: 3.0000e-05
# Epoch 29/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.5884 - auc: 0.7866 - loss: 1.1900 - val_accuracy: 0.5941 - val_auc: 0.7685 - val_loss: 1.2151 - learning_rate: 3.0000e-05
# Epoch 30/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.5586 - auc: 0.7657 - loss: 1.1717 - val_accuracy: 0.7426 - val_auc: 0.8230 - val_loss: 1.1683 - learning_rate: 3.0000e-05
# Epoch 31/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.6415 - auc: 0.7979 - loss: 1.1580 - val_accuracy: 0.6238 - val_auc: 0.7861 - val_loss: 1.1588 - learning_rate: 3.0000e-05
# Epoch 32/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.5286 - auc: 0.7388 - loss: 1.1418 - val_accuracy: 0.6436 - val_auc: 0.8017 - val_loss: 1.1326 - learning_rate: 3.0000e-05
# Epoch 33/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.6184 - auc: 0.8228 - loss: 1.1113 - val_accuracy: 0.6931 - val_auc: 0.8364 - val_loss: 1.1022 - learning_rate: 3.0000e-05
# Epoch 34/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.6751 - auc: 0.8344 - loss: 1.0900 - val_accuracy: 0.6535 - val_auc: 0.8185 - val_loss: 1.1076 - learning_rate: 3.0000e-05
# Epoch 35/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.6666 - auc: 0.8471 - loss: 1.0695 - val_accuracy: 0.6238 - val_auc: 0.8026 - val_loss: 1.0774 - learning_rate: 3.0000e-05
# Epoch 36/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.6467 - auc: 0.8241 - loss: 1.0607 - val_accuracy: 0.5149 - val_auc: 0.7645 - val_loss: 1.0710 - learning_rate: 3.0000e-05
# Epoch 37/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.6635 - auc: 0.8377 - loss: 1.0392 - val_accuracy: 0.6040 - val_auc: 0.8037 - val_loss: 1.0533 - learning_rate: 3.0000e-05
# Epoch 38/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.6455 - auc: 0.8506 - loss: 1.0204 - val_accuracy: 0.6931 - val_auc: 0.8453 - val_loss: 1.0146 - learning_rate: 3.0000e-05
# Epoch 39/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.6414 - auc: 0.8514 - loss: 1.0010 - val_accuracy: 0.7228 - val_auc: 0.8589 - val_loss: 0.9871 - learning_rate: 3.0000e-05
# Epoch 40/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.7029 - auc: 0.8595 - loss: 0.9843 - val_accuracy: 0.6634 - val_auc: 0.8302 - val_loss: 0.9828 - learning_rate: 3.0000e-05
# Epoch 41/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.6900 - auc: 0.8721 - loss: 0.9645 - val_accuracy: 0.7129 - val_auc: 0.8619 - val_loss: 0.9594 - learning_rate: 3.0000e-05
# Epoch 42/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.7376 - auc: 0.8890 - loss: 0.9493 - val_accuracy: 0.7129 - val_auc: 0.8442 - val_loss: 0.9455 - learning_rate: 3.0000e-05
# Epoch 43/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.6771 - auc: 0.8648 - loss: 0.9337 - val_accuracy: 0.6733 - val_auc: 0.8435 - val_loss: 0.9453 - learning_rate: 3.0000e-05
# Epoch 44/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.7061 - auc: 0.8731 - loss: 0.9190 - val_accuracy: 0.5842 - val_auc: 0.7986 - val_loss: 0.9245 - learning_rate: 3.0000e-05
# Epoch 45/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.7090 - auc: 0.8872 - loss: 0.9018 - val_accuracy: 0.4851 - val_auc: 0.7437 - val_loss: 0.9784 - learning_rate: 3.0000e-05
# Epoch 46/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.7340 - auc: 0.8879 - loss: 0.8870 - val_accuracy: 0.6436 - val_auc: 0.8033 - val_loss: 0.9081 - learning_rate: 3.0000e-05
# Epoch 47/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.7700 - auc: 0.9180 - loss: 0.8652 - val_accuracy: 0.6337 - val_auc: 0.8274 - val_loss: 0.8914 - learning_rate: 3.0000e-05
# Epoch 48/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.7655 - auc: 0.9102 - loss: 0.8525 - val_accuracy: 0.5941 - val_auc: 0.8325 - val_loss: 0.8707 - learning_rate: 3.0000e-05
# Epoch 49/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.6731 - auc: 0.8687 - loss: 0.8502 - val_accuracy: 0.6337 - val_auc: 0.7879 - val_loss: 0.8750 - learning_rate: 3.0000e-05
# Epoch 50/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 57s 1s/step - accuracy: 0.7709 - auc: 0.9220 - loss: 0.8199 - val_accuracy: 0.6436 - val_auc: 0.8012 - val_loss: 0.8699 - learning_rate: 3.0000e-05
# Epoch 51/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.7708 - auc: 0.9218 - loss: 0.8094 - val_accuracy: 0.6337 - val_auc: 0.8018 - val_loss: 0.8705 - learning_rate: 3.0000e-05
# Epoch 52/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - accuracy: 0.7280 - auc: 0.8839 - loss: 0.8028 - val_accuracy: 0.5842 - val_auc: 0.8051 - val_loss: 0.8190 - learning_rate: 3.0000e-05
# Epoch 53/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.7794 - auc: 0.9232 - loss: 0.7774 - val_accuracy: 0.5545 - val_auc: 0.7906 - val_loss: 0.7958 - learning_rate: 3.0000e-05
# Epoch 54/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.7434 - auc: 0.8976 - loss: 0.7783 - val_accuracy: 0.5842 - val_auc: 0.7994 - val_loss: 0.8080 - learning_rate: 3.0000e-05
# Epoch 55/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.7939 - auc: 0.9191 - loss: 0.7575 - val_accuracy: 0.6337 - val_auc: 0.8097 - val_loss: 0.7664 - learning_rate: 3.0000e-05
# Epoch 56/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.8624 - auc: 0.9527 - loss: 0.7298 - val_accuracy: 0.6436 - val_auc: 0.8067 - val_loss: 0.7893 - learning_rate: 3.0000e-05
# Epoch 57/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.8175 - auc: 0.9291 - loss: 0.7296 - val_accuracy: 0.6337 - val_auc: 0.7789 - val_loss: 0.7855 - learning_rate: 1.5000e-05
# Epoch 58/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.8692 - auc: 0.9531 - loss: 0.7157 - val_accuracy: 0.6337 - val_auc: 0.7718 - val_loss: 0.7859 - learning_rate: 1.5000e-05
# Epoch 59/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.8486 - auc: 0.9513 - loss: 0.7076 - val_accuracy: 0.5941 - val_auc: 0.7703 - val_loss: 0.7752 - learning_rate: 1.5000e-05
# Epoch 60/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.7614 - auc: 0.9292 - loss: 0.7040 - val_accuracy: 0.6535 - val_auc: 0.8000 - val_loss: 0.7519 - learning_rate: 1.5000e-05
# Epoch 61/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.8354 - auc: 0.9289 - loss: 0.7078 - val_accuracy: 0.6436 - val_auc: 0.8181 - val_loss: 0.7553 - learning_rate: 1.5000e-05
# Epoch 62/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.8264 - auc: 0.9400 - loss: 0.6911 - val_accuracy: 0.6634 - val_auc: 0.8207 - val_loss: 0.7396 - learning_rate: 1.5000e-05
# Epoch 63/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.8368 - auc: 0.9454 - loss: 0.6852 - val_accuracy: 0.6832 - val_auc: 0.8123 - val_loss: 0.7241 - learning_rate: 1.5000e-05
# Epoch 64/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.8217 - auc: 0.9325 - loss: 0.6824 - val_accuracy: 0.6337 - val_auc: 0.8058 - val_loss: 0.7543 - learning_rate: 1.5000e-05
# Epoch 65/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.8636 - auc: 0.9543 - loss: 0.6669 - val_accuracy: 0.5842 - val_auc: 0.7780 - val_loss: 0.7454 - learning_rate: 1.5000e-05
# Epoch 66/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.8585 - auc: 0.9570 - loss: 0.6620 - val_accuracy: 0.6139 - val_auc: 0.7811 - val_loss: 0.7508 - learning_rate: 1.5000e-05
# Epoch 67/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.8565 - auc: 0.9639 - loss: 0.6540 - val_accuracy: 0.5644 - val_auc: 0.7633 - val_loss: 0.7505 - learning_rate: 1.5000e-05
# Epoch 68/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.8491 - auc: 0.9634 - loss: 0.6481 - val_accuracy: 0.6040 - val_auc: 0.7859 - val_loss: 0.7258 - learning_rate: 1.5000e-05
# Epoch 69/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.8749 - auc: 0.9659 - loss: 0.6392 - val_accuracy: 0.5941 - val_auc: 0.7864 - val_loss: 0.7337 - learning_rate: 1.5000e-05
# Epoch 70/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 0.8754 - auc: 0.9617 - loss: 0.6356 - val_accuracy: 0.5941 - val_auc: 0.8073 - val_loss: 0.6993 - learning_rate: 1.5000e-05
# Epoch 71/200
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 55s 1s/step - accuracy: 0.8406 - auc: 0.9549 - loss: 0.6357 - val_accuracy: 0.5941 - val_auc: 0.7979 - val_loss: 0.7196 - learning_rate: 1.5000e-05
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 63s 5s/step
#
# ============================================================
# TRI-CLASS RESULT - SEQUENCE LEVEL
#               precision    recall  f1-score   support
#
#        Adeno       0.60      0.47      0.53        19
#        Small       0.30      0.46      0.36        13
#     Squamous       0.93      0.78      0.85        18
#
#     accuracy                           0.58        50
#    macro avg       0.61      0.57      0.58        50
# weighted avg       0.64      0.58      0.60        50
#
#
# TRI-CLASS RESULT - PATIENT LEVEL (CONFIDENCE-WEIGHTED)
#               precision    recall  f1-score   support
#
#        Adeno       0.50      0.25      0.33         4
#        Small       0.20      0.33      0.25         3
#     Squamous       0.67      0.67      0.67         3
#
#     accuracy                           0.40        10
#    macro avg       0.46      0.42      0.42        10
# weighted avg       0.46      0.40      0.41        10
